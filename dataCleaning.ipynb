# %%
from bs4 import BeautifulSoup

# %%
path = 'produced_data/raw_data/compagneheader.xml'

with open(path, 'r', encoding='utf-8') as f:

    soup = BeautifulSoup(f, features='xml')

    persName = [para.get_text() for para in soup.find_all('placeName')]

    for i in soup.find_all('person'):
        i = i['xml:id'][:2].upper() + i['xml:id'][2:]
        print(i)
# Out:
# DMaar
# PPicasso
# HCartierBesson
# RCapa
# FFranco
# MAnray
# FGilot
# AMartin
# AGorky
# JMiro
# WDKooning
# DTSuzuki
# FMitchell
# RIndiana
# EKelly
# JYoungerman
# DSeyrig
# JRosenquist
# CHinman
# MErnst
# OKokoschka
# WAmozart
# MRothko
# SLewitt
# RRyman
# DJudd
# RIndiana
# AReinhardt
# DHopper
# MMerz
# MMerz2
# FCasorati
# GCelant
# CAbate
# FSargentini
# NDSaintPhalle
# JTinguely
# PKlee
# HMatisse
# ULinde
# GGarbo
# POlofUltved
# MCaraccioloAgnelli
# ECatalano
# FFellini
# MMastroianni
# LVisconti
# ABonitooliva
# GLonardi
# ABoetti
# JBeuys
# GDdominicis
# GProusch
# GPassmore
# JKounellis
# EMattiacci
# MPistoletto
# CTacchi
# VPisani
# FMauri
# DAnka
# FWoodman
# GCasetti
# MAldororrome
# SMirri
# GGallo
# CSherman
# SCalle
# NGoldin
# DArbus
# AArbus
# TBrowning
# CLeopatra
# WShakespeare
# CRama
# GVercelli
# ESanguineti
# ASoldati
# GDorfles
# BMunari
# GMonet
# GBertasso
# CLeviStrauss
# LVergine
# EHesse
# TDoyle
# ADanto
# BSchwabsky
# ZHadid
# RKoolhaas
# WFehlbaum
# TAndo
# FGehry
# GAulenti
# GPonti
# GRopius
# LEcorbusier
# LWright
# ENrogers
# AOlivetti
# LNissimMomigliano
# FMomigliano
# GSoavi
# RZorzi
# GAgnelli
# FBacon
# RLichtenstein
# LRonconi
# GPalomba
# COldenburg
# CVanbruggen
# EMaino
# LFontana
# LBourgeois
# LBourgeois2
# FLeger
# ABreton
# RGoldwater
# MDuchamp
# JMccarthy
# ABarr
# RMapplethorpe
